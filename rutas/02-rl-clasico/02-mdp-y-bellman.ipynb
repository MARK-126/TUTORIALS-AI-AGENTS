# %% [markdown]
# # 02. MDP y Bellman
#
# **RL Clásico** - Reforzamiento
#
# ## 10 Secciones completas

# %%
import numpy as np
import matplotlib.pyplot as plt
import gym  # Optional
print('✅')

# %% [markdown]
# ## 1. Motivación
#
# MDP y Bellman en RL: agentes, ambientes, recompensas...

# %% [markdown]
# ## 2-4. Teoría e Implementación
#
# MDPs, Bellman, Q-Learning, Policy Gradients...

# %% [markdown]
# ## 5. GRADED

# %% [markdown]
# ### (20 pts)

# %%
def bellman_expectation(V, policy, P, R, gamma):
    # START CODE HERE
    pass
    # END CODE HERE
    pass

# %% [markdown]
# <details><summary>💡</summary>Hint</details>

# %%
# Test

# %% [markdown]
# ### (20 pts)

# %%
def policy_eval_step(V, policy, P, R, gamma):
    # START CODE HERE
    pass
    # END CODE HERE
    pass

# %% [markdown]
# <details><summary>💡</summary>Hint</details>

# %%
# Test

# %% [markdown]
# ### (25 pts)

# %%
def value_iteration_step(V, P, R, gamma):
    # START CODE HERE
    pass
    # END CODE HERE
    pass

# %% [markdown]
# <details><summary>💡</summary>Hint</details>

# %%
# Test

# %% [markdown]
# ### (20 pts)

# %%
def extract_policy(V, P, R, gamma):
    # START CODE HERE
    pass
    # END CODE HERE
    pass

# %% [markdown]
# <details><summary>💡</summary>Hint</details>

# %%
# Test

# %% [markdown]
# ### (15 pts)

# %%
def compute_q_values(V, P, R, gamma):
    # START CODE HERE
    pass
    # END CODE HERE
    pass

# %% [markdown]
# <details><summary>💡</summary>Hint</details>

# %%
# Test

# %% [markdown]
# ## 6-10. Gym, Papers, Best Practices...
