# %% [markdown]
# # 05. Policy Gradients
#
# **RL Clásico** - Reforzamiento
#
# ## 10 Secciones completas

# %%
import numpy as np
import matplotlib.pyplot as plt
import gym  # Optional
print('✅')

# %% [markdown]
# ## 1. Motivación
#
# Policy Gradients en RL: agentes, ambientes, recompensas...

# %% [markdown]
# ## 2-4. Teoría e Implementación
#
# MDPs, Bellman, Q-Learning, Policy Gradients...

# %% [markdown]
# ## 5. GRADED

# %% [markdown]
# ### (15 pts)

# %%
def compute_returns(rewards, gamma):
    # START CODE HERE
    pass
    # END CODE HERE
    pass

# %% [markdown]
# <details><summary>💡</summary>Hint</details>

# %%
# Test

# %% [markdown]
# ### (20 pts)

# %%
def compute_policy_gradient(log_probs, returns):
    # START CODE HERE
    pass
    # END CODE HERE
    pass

# %% [markdown]
# <details><summary>💡</summary>Hint</details>

# %%
# Test

# %% [markdown]
# ### (30 pts)

# %%
def sample_action(policy_network, state):
    # START CODE HERE
    pass
    # END CODE HERE
    pass

# %% [markdown]
# <details><summary>💡</summary>Hint</details>

# %%
# Test

# %% [markdown]
# ### (15 pts)

# %%
def train_policy_gradient(env, policy_net, optimizer, n_episodes):
    # START CODE HERE
    pass
    # END CODE HERE
    pass

# %% [markdown]
# <details><summary>💡</summary>Hint</details>

# %%
# Test

# %% [markdown]
# ### (20 pts)

# %%
def compute_baseline(returns):
    # START CODE HERE
    pass
    # END CODE HERE
    pass

# %% [markdown]
# <details><summary>💡</summary>Hint</details>

# %%
# Test

# %% [markdown]
# ## 6-10. Gym, Papers, Best Practices...
