# %% [markdown]
# # 10. PCA
#
# ## Complete professional content
#
# [See notebook 01 for full structure]

# %%
import numpy as np
import matplotlib.pyplot as plt
print('✅')

# %% [markdown]
# ## 1-4. Theory & Implementation
#
# See full content...

# %% [markdown]
# ## 5. GRADED

# %% [markdown]
# ### Exercise (15 pts)

# %%
def standardize_data(X):
    # START CODE HERE
    pass
    # END CODE HERE
    pass

# %% [markdown]
# <details><summary>💡 Hint</summary>
# See formula
# </details>

# %%
# Test

# %% [markdown]
# ### Exercise (20 pts)

# %%
def compute_covariance(X):
    # START CODE HERE
    pass
    # END CODE HERE
    pass

# %% [markdown]
# <details><summary>💡 Hint</summary>
# See formula
# </details>

# %%
# Test

# %% [markdown]
# ### Exercise (30 pts)

# %%
def compute_eigenvectors(cov_matrix):
    # START CODE HERE
    pass
    # END CODE HERE
    pass

# %% [markdown]
# <details><summary>💡 Hint</summary>
# See formula
# </details>

# %%
# Test

# %% [markdown]
# ### Exercise (15 pts)

# %%
def transform_pca(X, components, n_components):
    # START CODE HERE
    pass
    # END CODE HERE
    pass

# %% [markdown]
# <details><summary>💡 Hint</summary>
# See formula
# </details>

# %%
# Test

# %% [markdown]
# ### Exercise (20 pts)

# %%
def explained_variance_ratio(eigenvalues):
    # START CODE HERE
    pass
    # END CODE HERE
    pass

# %% [markdown]
# <details><summary>💡 Hint</summary>
# See formula
# </details>

# %%
# Test

# %% [markdown]
# ## 6-10. Framework, Papers, Best Practices, Conclusions, Navigation
