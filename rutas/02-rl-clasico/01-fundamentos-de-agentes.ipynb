# %% [markdown]
# # 01. Fundamentos de Agentes
#
# **RL Clásico** - Reforzamiento
#
# ## 10 Secciones completas

# %%
import numpy as np
import matplotlib.pyplot as plt
import gym  # Optional
print('✅')

# %% [markdown]
# ## 1. Motivación
#
# Fundamentos de Agentes en RL: agentes, ambientes, recompensas...

# %% [markdown]
# ## 2-4. Teoría e Implementación
#
# MDPs, Bellman, Q-Learning, Policy Gradients...

# %% [markdown]
# ## 5. GRADED

# %% [markdown]
# ### (20 pts)

# %%
def implement_environment(size, goal_pos):
    # START CODE HERE
    pass
    # END CODE HERE
    pass

# %% [markdown]
# <details><summary>💡</summary>Hint</details>

# %%
# Test

# %% [markdown]
# ### (20 pts)

# %%
def random_agent_policy(state):
    # START CODE HERE
    pass
    # END CODE HERE
    pass

# %% [markdown]
# <details><summary>💡</summary>Hint</details>

# %%
# Test

# %% [markdown]
# ### (25 pts)

# %%
def greedy_policy(state, q_table):
    # START CODE HERE
    pass
    # END CODE HERE
    pass

# %% [markdown]
# <details><summary>💡</summary>Hint</details>

# %%
# Test

# %% [markdown]
# ### (20 pts)

# %%
def compute_episode_return(rewards, gamma):
    # START CODE HERE
    pass
    # END CODE HERE
    pass

# %% [markdown]
# <details><summary>💡</summary>Hint</details>

# %%
# Test

# %% [markdown]
# ### (15 pts)

# %%
def compare_agents(env, policies, n_episodes):
    # START CODE HERE
    pass
    # END CODE HERE
    pass

# %% [markdown]
# <details><summary>💡</summary>Hint</details>

# %%
# Test

# %% [markdown]
# ## 6-10. Gym, Papers, Best Practices...
