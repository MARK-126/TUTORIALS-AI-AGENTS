# %% [markdown]
# # 08. SVM
#
# ## Complete professional content
#
# [See notebook 01 for full structure]

# %%
import numpy as np
import matplotlib.pyplot as plt
print('✅')

# %% [markdown]
# ## 1-4. Theory & Implementation
#
# See full content...

# %% [markdown]
# ## 5. GRADED

# %% [markdown]
# ### Exercise (15 pts)

# %%
def compute_hinge_loss(y_true, y_pred):
    # START CODE HERE
    pass
    # END CODE HERE
    pass

# %% [markdown]
# <details><summary>💡 Hint</summary>
# See formula
# </details>

# %%
# Test

# %% [markdown]
# ### Exercise (20 pts)

# %%
def compute_svm_gradient(X, y, w, b, C):
    # START CODE HERE
    pass
    # END CODE HERE
    pass

# %% [markdown]
# <details><summary>💡 Hint</summary>
# See formula
# </details>

# %%
# Test

# %% [markdown]
# ### Exercise (30 pts)

# %%
def train_svm(X, y, C, lr, epochs):
    # START CODE HERE
    pass
    # END CODE HERE
    pass

# %% [markdown]
# <details><summary>💡 Hint</summary>
# See formula
# </details>

# %%
# Test

# %% [markdown]
# ### Exercise (15 pts)

# %%
def predict_svm(X, w, b):
    # START CODE HERE
    pass
    # END CODE HERE
    pass

# %% [markdown]
# <details><summary>💡 Hint</summary>
# See formula
# </details>

# %%
# Test

# %% [markdown]
# ### Exercise (20 pts)

# %%
def compute_margin(X, y, w, b):
    # START CODE HERE
    pass
    # END CODE HERE
    pass

# %% [markdown]
# <details><summary>💡 Hint</summary>
# See formula
# </details>

# %%
# Test

# %% [markdown]
# ## 6-10. Framework, Papers, Best Practices, Conclusions, Navigation
