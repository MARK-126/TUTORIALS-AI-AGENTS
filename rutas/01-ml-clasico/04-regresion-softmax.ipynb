# %% [markdown]
# # 04. Regresión Softmax
#
# **Nivel:** 🟡 | **Tiempo:** 75-90 min | **Prereq:** Python, NumPy
#
# ## 📋 Tabla de Contenidos
#
# 1. [Motivación](#1-motivacion)
# 2. [Intuición Visual](#2-intuicion)
# 3. [Fundamentos Matemáticos](#3-fundamentos)
# 4. [Implementación Desde Cero](#4-implementacion)
# 5. [**🎯 Ejercicios GRADED**](#5-graded) ⭐
# 6. [Versión con Framework](#6-framework)
# 7. [Papers Fundamentales](#7-papers)
# 8. [Best Practices](#8-practices)
# 9. [Conclusiones](#9-conclusiones)
# 10. [Referencias y Navegación](#10-nav)
#
# ## 🎯 Objetivos de Aprendizaje
#
# Dominar Regresión Softmax desde fundamentos matemáticos hasta implementación práctica.

# %% [markdown]
# ### Ejercicio: Implementar función básica (15 pts)
#
# **Instrucciones:**
# 1. Completa el código entre `# START CODE` y `# END CODE`
# 2. Ejecuta el test para verificar

# %%
def softmax_function(z):
    """Implementar función básica"""
    # START CODE HERE
    result = None
    # END CODE HERE
    return result

# %% [markdown]
# <details><summary>💡 Hint</summary>
#
# hint1
# </details>
#
# <details><summary>🔑 Solución</summary>
#
# ```python
# code
# ```
# </details>

# %%
# Test
print('Testing softmax_function...')
try:
    # result = softmax_function(...)
    print('Expected: ')
    print('✅ +15 pts')
except: print('❌ Error')

# %% [markdown]
# ### Ejercicio: Calcular métrica (20 pts)
#
# **Instrucciones:**
# 1. Completa el código entre `# START CODE` y `# END CODE`
# 2. Ejecuta el test para verificar

# %%
def categorical_cross_entropy(y_true, y_pred):
    """Calcular métrica"""
    # START CODE HERE
    result = None
    # END CODE HERE
    return result

# %% [markdown]
# <details><summary>💡 Hint</summary>
#
# hint
# </details>
#
# <details><summary>🔑 Solución</summary>
#
# ```python
# code
# ```
# </details>

# %%
# Test
print('Testing categorical_cross_entropy...')
try:
    # result = categorical_cross_entropy(...)
    print('Expected: ')
    print('✅ +20 pts')
except: print('❌ Error')

# %% [markdown]
# ### Ejercicio: Entrenar modelo (30 pts)
#
# **Instrucciones:**
# 1. Completa el código entre `# START CODE` y `# END CODE`
# 2. Ejecuta el test para verificar

# %%
def train_softmax(X, y, num_classes, learning_rate, epochs):
    """Entrenar modelo"""
    # START CODE HERE
    result = None
    # END CODE HERE
    return result

# %% [markdown]
# <details><summary>💡 Hint</summary>
#
# hint
# </details>
#
# <details><summary>🔑 Solución</summary>
#
# ```python
# code
# ```
# </details>

# %%
# Test
print('Testing train_softmax...')
try:
    # result = train_softmax(...)
    print('Expected: ')
    print('✅ +30 pts')
except: print('❌ Error')

# %% [markdown]
# ### Ejercicio: Predicción (15 pts)
#
# **Instrucciones:**
# 1. Completa el código entre `# START CODE` y `# END CODE`
# 2. Ejecuta el test para verificar

# %%
def predict_multiclass(X, W, b):
    """Predicción"""
    # START CODE HERE
    result = None
    # END CODE HERE
    return result

# %% [markdown]
# <details><summary>💡 Hint</summary>
#
# hint
# </details>
#
# <details><summary>🔑 Solución</summary>
#
# ```python
# code
# ```
# </details>

# %%
# Test
print('Testing predict_multiclass...')
try:
    # result = predict_multiclass(...)
    print('Expected: ')
    print('✅ +15 pts')
except: print('❌ Error')

# %% [markdown]
# ### Ejercicio: Evaluación (20 pts)
#
# **Instrucciones:**
# 1. Completa el código entre `# START CODE` y `# END CODE`
# 2. Ejecuta el test para verificar

# %%
def compute_confusion_matrix(y_true, y_pred, num_classes):
    """Evaluación"""
    # START CODE HERE
    result = None
    # END CODE HERE
    return result

# %% [markdown]
# <details><summary>💡 Hint</summary>
#
# hint
# </details>
#
# <details><summary>🔑 Solución</summary>
#
# ```python
# code
# ```
# </details>

# %%
# Test
print('Testing compute_confusion_matrix...')
try:
    # result = compute_confusion_matrix(...)
    print('Expected: ')
    print('✅ +20 pts')
except: print('❌ Error')

# %% [markdown]
# ## 6. 🔧 Versión con Framework
#
# Implementación usando scikit-learn o bibliotecas estándar.

# %% [markdown]
# ## 7. 📄 Papers Fundamentales
#
# Papers clave sobre Regresión Softmax.

# %% [markdown]
# ## 8. ✅ Best Practices
#
# **✅ DO:**
# - Normalizar datos
# - Validar hiperparámetros
# - Usar cross-validation
#
# **❌ DON'T:**
# - Overfitting
# - Ignorar outliers

# %% [markdown]
# ## 9. 🎓 Conclusiones
#
# ### Conceptos Clave
#
# 1. Regresión Softmax es fundamental en ML
# 2. Implementación desde cero ayuda a entender
# 3. Frameworks optimizan para producción

# %% [markdown]
# ## 10. 📚 Referencias y Navegación
#
# ### Ruta 1: ML Clásico
#
# 1. [01 - Regresión Lineal](01-regresion-lineal.ipynb)
# 2. [02 - Gradient Descent](02-gradient-descent.ipynb)
# 3. [03 - Regresión Logística](03-regresion-logistica.ipynb)
# 4. [04 - Regresión Softmax](04-regresion-softmax.ipynb)
# 5. [05 - Árboles de Decisión](05-arboles-decision.ipynb)
# 6. [06 - Random Forests](06-random-forests.ipynb)
# 7. [07 - Boosting](07-boosting.ipynb)
# 8. [08 - SVM](08-svm.ipynb)
# 9. [09 - K-Means](09-kmeans.ipynb)
# 10. [10 - PCA](10-pca.ipynb)
#
# **[🏠 Volver al índice principal](../../README.md)**
