# %% [markdown]
# # 06. Actor-Critic
#
# **RL Clásico** - Reforzamiento
#
# ## 10 Secciones completas

# %%
import numpy as np
import matplotlib.pyplot as plt
import gym  # Optional
print('✅')

# %% [markdown]
# ## 1. Motivación
#
# Actor-Critic en RL: agentes, ambientes, recompensas...

# %% [markdown]
# ## 2-4. Teoría e Implementación
#
# MDPs, Bellman, Q-Learning, Policy Gradients...

# %% [markdown]
# ## 5. GRADED

# %% [markdown]
# ### (15 pts)

# %%
def compute_advantage(rewards, values, gamma):
    # START CODE HERE
    pass
    # END CODE HERE
    pass

# %% [markdown]
# <details><summary>💡</summary>Hint</details>

# %%
# Test

# %% [markdown]
# ### (20 pts)

# %%
def actor_loss(log_probs, advantages):
    # START CODE HERE
    pass
    # END CODE HERE
    pass

# %% [markdown]
# <details><summary>💡</summary>Hint</details>

# %%
# Test

# %% [markdown]
# ### (30 pts)

# %%
def critic_loss(values, returns):
    # START CODE HERE
    pass
    # END CODE HERE
    pass

# %% [markdown]
# <details><summary>💡</summary>Hint</details>

# %%
# Test

# %% [markdown]
# ### (15 pts)

# %%
def train_actor_critic(env, actor, critic, optimizer, n_episodes):
    # START CODE HERE
    pass
    # END CODE HERE
    pass

# %% [markdown]
# <details><summary>💡</summary>Hint</details>

# %%
# Test

# %% [markdown]
# ### (20 pts)

# %%
def compute_gae(rewards, values, gamma, lambda_):
    # START CODE HERE
    pass
    # END CODE HERE
    pass

# %% [markdown]
# <details><summary>💡</summary>Hint</details>

# %%
# Test

# %% [markdown]
# ## 6-10. Gym, Papers, Best Practices...
