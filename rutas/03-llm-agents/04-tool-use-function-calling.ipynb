# %% [markdown]
# # 04. Tool Use y Function Calling
#
# **Nivel:** 🟡 Intermedio
# **Tiempo:** 90-120 min
# **Prerequisites:** 01-03
#
# ## 🎯 Objetivos
#
# - Definir schemas de herramientas (OpenAI/Anthropic format)
# - Validar function calls programáticamente
# - Ejecutar herramientas de forma segura
# - Componer múltiples tools
# - **Implementar 5 funciones core (100 pts)**
#
# ## 📋 TOC
#
# 1. [Motivación](#1-motivacion)
# 2. [Fundamentos](#2-fundamentos)
# 3. [Implementación](#3-implementacion)
# 4. [Frameworks](#4-frameworks)
# 5. [🎓 Ejercicios GRADED (100 pts)](#5-ejercicios-graded)
# 6. [Ejercicios Avanzados](#6-ejercicios-avanzados)
# 7. [📄 Papers](#7-papers)
# 8. [💡 Best Practices](#8-best-practices)
# 9. [📍 Navegación](#9-navegacion)

# %% [markdown]
# ### Ejercicio: Implementar función básica (15 pts)
#
# **Instrucciones:**
# 1. Completa el código entre `# START CODE` y `# END CODE`
# 2. Ejecuta el test para verificar

# %%
def define_tool_schema(tool_name, description, parameters):
    """Implementar función básica"""
    # START CODE HERE
    result = None
    # END CODE HERE
    return result

# %% [markdown]
# <details><summary>💡 Hint</summary>
#
# hint1
# </details>
#
# <details><summary>🔑 Solución</summary>
#
# ```python
# code
# ```
# </details>

# %%
# Test
print('Testing define_tool_schema...')
try:
    # result = define_tool_schema(...)
    print('Expected: ')
    print('✅ +15 pts')
except: print('❌ Error')

# %% [markdown]
# ### Ejercicio: Calcular métrica (20 pts)
#
# **Instrucciones:**
# 1. Completa el código entre `# START CODE` y `# END CODE`
# 2. Ejecuta el test para verificar

# %%
def validate_function_call(call, schema):
    """Calcular métrica"""
    # START CODE HERE
    result = None
    # END CODE HERE
    return result

# %% [markdown]
# <details><summary>💡 Hint</summary>
#
# hint
# </details>
#
# <details><summary>🔑 Solución</summary>
#
# ```python
# code
# ```
# </details>

# %%
# Test
print('Testing validate_function_call...')
try:
    # result = validate_function_call(...)
    print('Expected: ')
    print('✅ +20 pts')
except: print('❌ Error')

# %% [markdown]
# ### Ejercicio: Entrenar modelo (30 pts)
#
# **Instrucciones:**
# 1. Completa el código entre `# START CODE` y `# END CODE`
# 2. Ejecuta el test para verificar

# %%
def execute_function_safely(function, args):
    """Entrenar modelo"""
    # START CODE HERE
    result = None
    # END CODE HERE
    return result

# %% [markdown]
# <details><summary>💡 Hint</summary>
#
# hint
# </details>
#
# <details><summary>🔑 Solución</summary>
#
# ```python
# code
# ```
# </details>

# %%
# Test
print('Testing execute_function_safely...')
try:
    # result = execute_function_safely(...)
    print('Expected: ')
    print('✅ +30 pts')
except: print('❌ Error')

# %% [markdown]
# ### Ejercicio: Predicción (15 pts)
#
# **Instrucciones:**
# 1. Completa el código entre `# START CODE` y `# END CODE`
# 2. Ejecuta el test para verificar

# %%
def compose_tools(tools, sequence):
    """Predicción"""
    # START CODE HERE
    result = None
    # END CODE HERE
    return result

# %% [markdown]
# <details><summary>💡 Hint</summary>
#
# hint
# </details>
#
# <details><summary>🔑 Solución</summary>
#
# ```python
# code
# ```
# </details>

# %%
# Test
print('Testing compose_tools...')
try:
    # result = compose_tools(...)
    print('Expected: ')
    print('✅ +15 pts')
except: print('❌ Error')

# %% [markdown]
# ### Ejercicio: Evaluación (20 pts)
#
# **Instrucciones:**
# 1. Completa el código entre `# START CODE` y `# END CODE`
# 2. Ejecuta el test para verificar

# %%
def handle_tool_errors(error, context):
    """Evaluación"""
    # START CODE HERE
    result = None
    # END CODE HERE
    return result

# %% [markdown]
# <details><summary>💡 Hint</summary>
#
# hint
# </details>
#
# <details><summary>🔑 Solución</summary>
#
# ```python
# code
# ```
# </details>

# %%
# Test
print('Testing handle_tool_errors...')
try:
    # result = handle_tool_errors(...)
    print('Expected: ')
    print('✅ +20 pts')
except: print('❌ Error')

# %% [markdown]
# ## 6. Seguridad y Sandboxing
#
# ### Consideraciones de Seguridad
#
# 1. **Input Validation**: Siempre validar argumentos contra schema
# 2. **Sandboxing**: Ejecutar código en entorno aislado
# 3. **Rate Limiting**: Limitar llamadas a APIs externas
# 4. **Access Control**: Verificar permisos antes de ejecutar
# 5. **Logging**: Registrar todas las ejecuciones para auditoría

# %% [markdown]
# <a id="5-ejercicios-graded"></a>
# ## 5. 🎓 Ejercicios GRADED (100 pts)
#
# ### Ejercicios
# 1. define_tool_schema (20 pts)
# 2. validate_function_call (20 pts)
# 3. execute_function_safely (20 pts)
# 4. compose_tools (20 pts)
# 5. handle_tool_errors (20 pts)

# %%
import sys
sys.path.append("/home/user/TUTORIALS-AI-AGENTS/rutas/03-llm-agents")
from tests.test_04_tool_use import ToolUseFunctionCallingGrader

grader = ToolUseFunctionCallingGrader()
print(f"✅ Grader: {grader.total_points} pts")

# %% [markdown]
# ### Ejercicio 1: Definir schema de tool (20 pts)
#
# **Instrucciones:**
# 1. Completa el código entre `# START CODE HERE` y `# END CODE HERE`
# 2. Ejecuta el test para verificar tu implementación

# %%
def define_tool_schema(tool_name, description, parameters):
    """Definir schema de tool"""
    # START CODE HERE (≈ 3-10 líneas)
    result = None  # Tu código aquí
    # END CODE HERE
    return result

# %% [markdown]
# <details><summary>💡 Hint</summary>
#
# OpenAI/Anthropic format
# </details>
#
# <details><summary>🔑 Solución</summary>
#
# ```python
# # Implementa define_tool_schema aquí
# # Ver autograder para tests específicos
# ```
# </details>

# %%
# 🧪 Test de define_tool_schema
print('Testing define_tool_schema...')
print('-' * 50)
try:
    # result = define_tool_schema(...)  # Descomenta y completa
    # print(f'Result: {result}')
    print('Expected: JSON schema')
    print('✅ Test passed! +20 pts')
except Exception as e:
    print(f'❌ Error: {e}')

# %%
# GRADED
def validate_function_call(...):
    pass

# %%
# grader.test_validate_function_call(validate_function_call)

# %% [markdown]
# ### Ejercicio 2: Validar function call (20 pts)
#
# **Instrucciones:**
# 1. Completa el código entre `# START CODE HERE` y `# END CODE HERE`
# 2. Ejecuta el test para verificar tu implementación

# %%
def validate_function_call(call, schema):
    """Validar function call"""
    # START CODE HERE (≈ 3-10 líneas)
    result = None  # Tu código aquí
    # END CODE HERE
    return result

# %% [markdown]
# <details><summary>💡 Hint</summary>
#
# Verifica tipos y required
# </details>
#
# <details><summary>🔑 Solución</summary>
#
# ```python
# # Implementa validate_function_call aquí
# # Ver autograder para tests específicos
# ```
# </details>

# %%
# 🧪 Test de validate_function_call
print('Testing validate_function_call...')
print('-' * 50)
try:
    # result = validate_function_call(...)  # Descomenta y completa
    # print(f'Result: {result}')
    print('Expected: is_valid, errors')
    print('✅ Test passed! +20 pts')
except Exception as e:
    print(f'❌ Error: {e}')

# %%
# GRADED
def compose_tools(...):
    pass

# %%
# grader.test_compose_tools(compose_tools)

# %% [markdown]
# ### Ejercicio 3: Ejecutar función de forma segura (20 pts)
#
# **Instrucciones:**
# 1. Completa el código entre `# START CODE HERE` y `# END CODE HERE`
# 2. Ejecuta el test para verificar tu implementación

# %%
def execute_function_safely(function, args):
    """Ejecutar función de forma segura"""
    # START CODE HERE (≈ 3-10 líneas)
    result = None  # Tu código aquí
    # END CODE HERE
    return result

# %% [markdown]
# <details><summary>💡 Hint</summary>
#
# Try-catch con timeout
# </details>
#
# <details><summary>🔑 Solución</summary>
#
# ```python
# # Implementa execute_function_safely aquí
# # Ver autograder para tests específicos
# ```
# </details>

# %%
# 🧪 Test de execute_function_safely
print('Testing execute_function_safely...')
print('-' * 50)
try:
    # result = execute_function_safely(...)  # Descomenta y completa
    # print(f'Result: {result}')
    print('Expected: result or error')
    print('✅ Test passed! +20 pts')
except Exception as e:
    print(f'❌ Error: {e}')

# %%
# grader.grade_all({...})

# %%
# Ejemplo de sandboxing para ejecución de código
import subprocess
import tempfile

def execute_python_sandboxed(code: str, timeout: int = 5) -> Dict:
    """
    Ejecuta código Python en proceso separado con timeout.
    
    NOTA: Esto es una simplificación educativa.
    En producción usar containers (Docker) o servicios especializados.
    """
    try:
        # Crear archivo temporal
        with tempfile.NamedTemporaryFile(mode='w', suffix='.py', delete=False) as f:
            f.write(code)
            temp_file = f.name
        
        # Ejecutar con timeout
        result = subprocess.run(
            ['python', temp_file],
            capture_output=True,
            text=True,
            timeout=timeout
        )
        
        return {
            "stdout": result.stdout,
            "stderr": result.stderr,
            "returncode": result.returncode
        }
    
    except subprocess.TimeoutExpired:
        return {"error": "Timeout: código tomó más de 5 segundos"}
    except Exception as e:
        return {"error": str(e)}

# Ejemplo de uso
safe_code = "print('Hello from sandboxed environment!')"
result = execute_python_sandboxed(safe_code)
print("Sandboxed execution:")
print(result)

# %% [markdown]
# ## 7. Ejercicios
#
# ### 🟢 Ejercicio 1: Crear Nueva Herramienta

# %%
def ejercicio_1_email_tool():
    """
    Objetivo: Crear una herramienta de envío de email (simulado)
    
    Instrucciones:
    1. Define función send_email(to, subject, body)
    2. Crea Tool con JSON schema apropiado
    3. Agrega al agente
    4. Prueba con: "Envía un email a john@example.com sobre la reunión"
    """
    # TODO: Tu código aquí
    pass

# ejercicio_1_email_tool()

# %% [markdown]
# ### 🟡 Ejercicio 2: Tool Composition

# %%
def ejercicio_2_tool_composition():
    """
    Objetivo: Crear tarea que requiere múltiples herramientas
    
    Tarea: "Busca el clima en Madrid y Londres, compara las temperaturas y 
            dime cuál es más cálida y por cuántos grados"
    
    Requiere:
    - get_weather (2 veces)
    - calculate (para restar)
    - Razonamiento para sintetizar respuesta
    """
    # TODO: Tu código aquí
    pass

# ejercicio_2_tool_composition()

# %% [markdown]
# <a id="7-papers"></a>
# ## 7. 📄 Papers
#
# 1. **Toolformer** (Schick et al., 2023) - 2.8K citas
# 2. **Gorilla** (Patil et al., 2023) - API calling
# 3. **ToolLLM** (Qin et al., 2023) - 16K APIs
# 4. **OpenAI Function Calling** (2023)
# 5. **Anthropic Tool Use** (2024)
#
# [25+ papers adicionales omitidos por espacio]

# %% [markdown]
# <a id="8-best-practices"></a>
# ## 8. 💡 Best Practices
#
# - Siempre validar schemas
# - Sandbox para code execution
# - Retry con exponential backoff
# - Rate limiting

# %% [markdown]
# <a id="9-navegacion"></a>
# ## 9. 📍 Navegación
#
# ✅ Completaste Tool Use!
#
# **[➡️ Siguiente: 05. Memory Systems](05-memory-systems.ipynb)**
