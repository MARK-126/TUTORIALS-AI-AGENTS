# %% [markdown]
# # 03. Q Learning
#
# **Nivel:** 🔴 Avanzado | **Tiempo:** 90 min
#
# ## 📋 TOC
# 1. Motivación
# 2. Intuición
# 3. Matemática
# 4. Implementación
# 5. **🎯 GRADED** ⭐
# 6. Papers
# 7. Best Practices
# 8-10. Conclusiones/Refs/Nav

# %% [markdown]
# ### Ejercicio: Implementar función básica (15 pts)
#
# **Instrucciones:**
# 1. Completa el código entre `# START CODE` y `# END CODE`
# 2. Ejecuta el test para verificar

# %%
def initialize_q_table(n_states, n_actions):
    """Implementar función básica"""
    # START CODE HERE
    result = None
    # END CODE HERE
    return result

# %% [markdown]
# <details><summary>💡 Hint</summary>
#
# hint1
# </details>
#
# <details><summary>🔑 Solución</summary>
#
# ```python
# code
# ```
# </details>

# %%
# Test
print('Testing initialize_q_table...')
try:
    # result = initialize_q_table(...)
    print('Expected: ')
    print('✅ +15 pts')
except: print('❌ Error')

# %% [markdown]
# ### Ejercicio: Calcular métrica (20 pts)
#
# **Instrucciones:**
# 1. Completa el código entre `# START CODE` y `# END CODE`
# 2. Ejecuta el test para verificar

# %%
def epsilon_greedy(q_table, state, epsilon):
    """Calcular métrica"""
    # START CODE HERE
    result = None
    # END CODE HERE
    return result

# %% [markdown]
# <details><summary>💡 Hint</summary>
#
# hint
# </details>
#
# <details><summary>🔑 Solución</summary>
#
# ```python
# code
# ```
# </details>

# %%
# Test
print('Testing epsilon_greedy...')
try:
    # result = epsilon_greedy(...)
    print('Expected: ')
    print('✅ +20 pts')
except: print('❌ Error')

# %% [markdown]
# ### Ejercicio: Entrenar modelo (30 pts)
#
# **Instrucciones:**
# 1. Completa el código entre `# START CODE` y `# END CODE`
# 2. Ejecuta el test para verificar

# %%
def update_q_value(q_table, state, action, reward, next_state, alpha, gamma):
    """Entrenar modelo"""
    # START CODE HERE
    result = None
    # END CODE HERE
    return result

# %% [markdown]
# <details><summary>💡 Hint</summary>
#
# hint
# </details>
#
# <details><summary>🔑 Solución</summary>
#
# ```python
# code
# ```
# </details>

# %%
# Test
print('Testing update_q_value...')
try:
    # result = update_q_value(...)
    print('Expected: ')
    print('✅ +30 pts')
except: print('❌ Error')

# %% [markdown]
# ### Ejercicio: Predicción (15 pts)
#
# **Instrucciones:**
# 1. Completa el código entre `# START CODE` y `# END CODE`
# 2. Ejecuta el test para verificar

# %%
def train_q_learning(env, n_episodes, alpha, gamma, epsilon):
    """Predicción"""
    # START CODE HERE
    result = None
    # END CODE HERE
    return result

# %% [markdown]
# <details><summary>💡 Hint</summary>
#
# hint
# </details>
#
# <details><summary>🔑 Solución</summary>
#
# ```python
# code
# ```
# </details>

# %%
# Test
print('Testing train_q_learning...')
try:
    # result = train_q_learning(...)
    print('Expected: ')
    print('✅ +15 pts')
except: print('❌ Error')

# %% [markdown]
# ### Ejercicio: Evaluación (20 pts)
#
# **Instrucciones:**
# 1. Completa el código entre `# START CODE` y `# END CODE`
# 2. Ejecuta el test para verificar

# %%
def evaluate_policy(env, q_table, n_episodes):
    """Evaluación"""
    # START CODE HERE
    result = None
    # END CODE HERE
    return result

# %% [markdown]
# <details><summary>💡 Hint</summary>
#
# hint
# </details>
#
# <details><summary>🔑 Solución</summary>
#
# ```python
# code
# ```
# </details>

# %%
# Test
print('Testing evaluate_policy...')
try:
    # result = evaluate_policy(...)
    print('Expected: ')
    print('✅ +20 pts')
except: print('❌ Error')

# %% [markdown]
# ## 6. 📄 Papers
#
# Papers fundamentales del tema.

# %% [markdown]
# ## 7. ✅ Best Practices
#
# Mejores prácticas.

# %% [markdown]
# ## 8. 🎓 Conclusiones
#
# Conceptos clave.

# %% [markdown]
# ## 9. 📚 Referencias
#
# Recursos adicionales.

# %% [markdown]
# ## 10. 🧭 Navegación
#
# Ruta 02 RL - Notebook 03
